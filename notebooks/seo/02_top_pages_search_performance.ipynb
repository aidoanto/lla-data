# %% [markdown]
# # Top Pages Search Performance
#
# Use this notebook to identify which pages are carrying search performance and where page-level optimization is likely to pay off.
#
# ### Quick start (beginner-friendly)
# 1. Run the **Setup (run once)** cell.
# 2. In **Parameters**, choose `TOP_N` (how many pages to show).
# 3. Run the remaining cells from top to bottom.
#
# ### Links
# - GitHub repo: [github.com/aidanm-lla/lla-data](https://github.com/aidanm-lla/lla-data)
# - Open this notebook in Colab: [Top Pages Search Performance](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/seo/02_top_pages_search_performance.ipynb)
#
# ### Other notebooks
# - [Search Contribution Overview](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/seo/01_search_contribution_overview.ipynb)
# - [Query Drivers by Page](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/seo/03_query_drivers_by_page.ipynb)
# - [Opportunity Watchlist](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/seo/04_opportunity_watchlist.ipynb)
# - [Top Pages (Last 7 Days)](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/top_pages_last_7_days.ipynb)
# - [Traffic Source Quality](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/traffic_sources.ipynb)
# - [Time Patterns for Crisis-Related Pages](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/time_patterns.ipynb)
# - [Crisis Support Funnel](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/crisis_funnel.ipynb)
# - [Analysis Template](https://colab.research.google.com/github/aidanm-lla/lla-data/blob/main/notebooks/templates/analysis_template.ipynb)

# %%
#@title Setup (run once)
import sys
import os

if "google.colab" in sys.modules:
    from google.colab import auth
    auth.authenticate_user()
    if not os.path.exists("lla-data"):
        # !git clone -q https://github.com/aidoanto/lla-data.git
    repo = os.path.abspath("lla-data")
    if repo not in sys.path:
        sys.path.insert(0, repo)
    # !pip install -U -q "plotly>=6.1.1" "kaleido>=1.2.0"
else:
    for p in ("..", "../.."):
        ap = os.path.abspath(p)
        if ap not in sys.path:
            sys.path.insert(0, ap)

import plotly.express as px

import lifeline_theme
from lla_data import config
from lla_data.bq import build_date_params, default_query_window, get_client, run_query

lifeline_theme.inject_fonts()

client = get_client()
window = default_query_window(config.DEFAULT_DAYS_BACK)
# Out:
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# <link href="https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;600;700&family=Open+Sans+Condensed:wght@700&display=swap" rel="stylesheet">

# %%
#@title Parameters
TOP_N = 25 #@param {type:"integer"}

# %%
query = f"""
SELECT
  page_path,
  SUM(gsc_clicks) AS clicks,
  SUM(gsc_impressions) AS impressions,
  SAFE_DIVIDE(SUM(gsc_clicks), NULLIF(SUM(gsc_impressions), 0)) AS ctr,
  SAFE_DIVIDE(SUM(gsc_avg_position * gsc_impressions), NULLIF(SUM(gsc_impressions), 0)) AS avg_position,
  SUM(organic_sessions) AS organic_sessions
FROM `{config.PROJECT_ID}.{config.SEARCHCONSOLE_DATASET}.seo_page_daily`
WHERE report_date BETWEEN DATE(@start_date) AND DATE(@end_date)
GROUP BY page_path
HAVING impressions > 0
ORDER BY clicks DESC
LIMIT {TOP_N}
"""

df_pages = run_query(client, query, params=build_date_params(window))
df_pages.head()
# Out:
# /home/aido/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                                            page_path  clicks  impressions  \
# 0  /get-help/national-services/national-alcohol-o...   18878      1478261
# 1                                                  /   13188      1089572
# 2         /get-help/support-toolkit/topics/self-harm    2629       119885
# 3                                              /chat    2047       382179
# 4  /get-involved/volunteer/volunteer-as-a-crisis-...    1415        34572
#
#         ctr  avg_position  organic_sessions
# 0  0.012770      2.880884             17678
# 1  0.012104      6.749731             18608
# 2  0.021929      6.927055              2763
# 3  0.005356     10.282383              9889
# 4  0.040929      4.544082              1475

# %%
MAX_PATH_LABEL_LEN = 75
df_pages_plot = df_pages.copy()
df_pages_plot["page_path_label"] = df_pages_plot["page_path"].astype(str).apply(
    lambda p: p if len(p) <= MAX_PATH_LABEL_LEN else p[: MAX_PATH_LABEL_LEN - 1] + "\u2026"
)

analysis_window_label = f"{window.start_date} to {window.end_date}"

fig_clicks = px.bar(
    df_pages_plot.sort_values("clicks", ascending=True),
    x="clicks",
    y="page_path_label",
    orientation="h",
    hover_name="page_path",
    hover_data={"page_path_label": False},
    template="lifeline",
    title=f"Top {TOP_N} Pages by Search Clicks ({analysis_window_label})",
)
fig_clicks.update_layout(height=700, margin={"l": 420, "r": 40, "t": 80, "b": 40})
fig_clicks.update_yaxes(automargin=True)
lifeline_theme.add_lifeline_logo(fig_clicks)
fig_clicks.show()

fig_ctr = px.scatter(
    df_pages,
    x="avg_position",
    y="ctr",
    size="impressions",
    hover_name="page_path",
    template="lifeline",
    title=f"CTR vs Average Position (bubble size = impressions) ({analysis_window_label})",
)
fig_ctr.update_yaxes(tickformat=".0%")
fig_ctr.add_annotation(
    xref="paper",
    yref="paper",
    x=0,
    y=1.12,
    showarrow=False,
    align="left",
    text=(
        "Position is the average Google rank for a page (1 is best). "
        "CTR is click-through rate: clicks / impressions. "
        "Pages toward lower position numbers with higher CTR are generally performing better."
    ),
)
fig_ctr.update_layout(margin={"t": 140})
lifeline_theme.add_lifeline_logo(fig_ctr)
fig_ctr.show()
