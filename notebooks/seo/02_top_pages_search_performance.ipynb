# %% [markdown]
# # Top Pages Search Performance
#
# Use this notebook to identify which pages are carrying search performance and where page-level optimization is likely to pay off.

# %%
import sys
sys.path.insert(0, "..")
sys.path.insert(0, "../..")

import plotly.express as px

import lifeline_theme
from lla_data import config
from lla_data.bq import build_date_params, default_query_window, get_client, run_query

lifeline_theme.inject_fonts()

client = get_client()
window = default_query_window(config.DEFAULT_DAYS_BACK)
TOP_N = config.DEFAULT_TOP_N
# Out:
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# <link href="https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;600;700&family=Open+Sans+Condensed:wght@700&display=swap" rel="stylesheet">

# %%
query = f"""
SELECT
  page_path,
  SUM(gsc_clicks) AS clicks,
  SUM(gsc_impressions) AS impressions,
  SAFE_DIVIDE(SUM(gsc_clicks), NULLIF(SUM(gsc_impressions), 0)) AS ctr,
  SAFE_DIVIDE(SUM(gsc_avg_position * gsc_impressions), NULLIF(SUM(gsc_impressions), 0)) AS avg_position,
  SUM(organic_sessions) AS organic_sessions
FROM `{config.PROJECT_ID}.{config.SEARCHCONSOLE_DATASET}.seo_page_daily`
WHERE report_date BETWEEN DATE(@start_date) AND DATE(@end_date)
GROUP BY page_path
HAVING impressions > 0
ORDER BY clicks DESC
LIMIT {TOP_N}
"""

df_pages = run_query(client, query, params=build_date_params(window))
df_pages.head()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[2], line 17
#       1 query = f"""
#       2 SELECT
#       3   page_path,
#    (...)     14 LIMIT {TOP_N}
#      15 """
# ---> 17 df_pages = run_query(client, query, params=build_date_params(window))
#      18 df_pages.head()
#
# File ~/projects/lla-data/notebooks/seo/../../lla_data/bq.py:75, in run_query(client, sql, params, dry_run, max_bytes_billed)
#      65 """Execute SQL and return a pandas DataFrame.
#      66
#      67 Set dry_run=True while developing queries to inspect cost first.
#      68 """
#      69 job_config = bigquery.QueryJobConfig(
#      70     query_parameters=list(params or []),
#      71     dry_run=dry_run,
#      72     use_query_cache=not dry_run,
#      73     maximum_bytes_billed=max_bytes_billed,
#      74 )
# ---> 75 job = client.query(sql, job_config=job_config)
#      77 if dry_run:
#      78     processed = int(job.total_bytes_processed or 0)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/client.py:3590, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method, timestamp_precision)
#    3578     return _job_helpers.query_jobs_query(
#    3579         self,
#    3580         query,
#    (...)   3587         timestamp_precision=timestamp_precision,
#    3588     )
#    3589 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3590     return _job_helpers.query_jobs_insert(
#    3591         self,
#    3592         query,
#    3593         job_config,
#    3594         job_id,
#    3595         job_id_prefix,
#    3596         location,
#    3597         project,
#    3598         retry,
#    3599         timeout,
#    3600         job_retry,
#    3601     )
#    3602 else:
#    3603     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/_job_helpers.py:205, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, callback)
#     202 if job_retry is not None:
#     203     do_query = google.cloud.bigquery.retry._DEFAULT_QUERY_JOB_INSERT_RETRY(do_query)
# --> 205 future = do_query()
#     207 # The future might be in a failed state now, but if it's
#     208 # unrecoverable, we'll find out when we ask for it's result, at which
#     209 # point, we may retry.
#     210 if not job_id_given:
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/_job_helpers.py:151, in query_jobs_insert.<locals>.do_query()
#     148 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#     150 try:
# --> 151     query_job._begin(retry=retry, timeout=timeout)
#     152     if job_config is not None and not job_config.dry_run:
#     153         callback(
#     154             query_sent_factory(
#     155                 query=query,
#    (...)    160             )
#     161         )
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/job/query.py:1465, in QueryJob._begin(self, client, retry, timeout)
#    1445 """API call:  begin the job via a POST request
#    1446
#    1447 See
#    (...)   1461     ValueError: If the job has already begun.
#    1462 """
#    1464 try:
# -> 1465     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1466 except exceptions.GoogleAPICallError as exc:
#    1467     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1468         message=exc.message, location=self.location, job_id=self.job_id
#    1469     )
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/job/base.py:825, in _AsyncJob._begin(self, client, retry, timeout)
#     822 # jobs.insert is idempotent because we ensure that every new
#     823 # job has an ID.
#     824 span_attributes = {"path": path}
# --> 825 api_response = client._call_api(
#     826     retry,
#     827     span_name="BigQuery.job.begin",
#     828     span_attributes=span_attributes,
#     829     job_ref=self,
#     830     method="POST",
#     831     path=path,
#     832     data=self.to_api_repr(),
#     833     timeout=timeout,
#     834 )
#     835 self._set_properties(api_response)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/bigquery/client.py:861, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     857 if span_name is not None:
#     858     with create_span(
#     859         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     860     ):
# --> 861         return call()
#     863 return call()
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/projects/lla-data/.venv/lib/python3.14/site-packages/google/cloud/_http/__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)    490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# BadRequest: 400 POST https://bigquery.googleapis.com/bigquery/v2/projects/lifeline-website-480522/jobs?prettyPrint=false: Invalid value at 'job.configuration.query.maximum_bytes_billed.value' (TYPE_INT64), "None"
#
# Location: australia-southeast1
# Job ID: 9fd7e54d-62f7-445c-9817-e49d315b6e8f
#  [{'@type': 'type.googleapis.com/google.rpc.BadRequest', 'fieldViolations': [{'field': 'job.configuration.query.maximum_bytes_billed.value', 'description': 'Invalid value at \'job.configuration.query.maximum_bytes_billed.value\' (TYPE_INT64), "None"'}]}]

# %%
fig_clicks = px.bar(
    df_pages.sort_values("clicks", ascending=True),
    x="clicks",
    y="page_path",
    orientation="h",
    template="lifeline",
    title=f"Top {TOP_N} Pages by Search Clicks",
)
fig_clicks.update_layout(height=700, margin={"l": 260})
lifeline_theme.add_lifeline_logo(fig_clicks)
fig_clicks.show()

fig_ctr = px.scatter(
    df_pages,
    x="avg_position",
    y="ctr",
    size="impressions",
    hover_name="page_path",
    template="lifeline",
    title="CTR vs Average Position (bubble size = impressions)",
)
fig_ctr.update_yaxes(tickformat=".0%")
lifeline_theme.add_lifeline_logo(fig_ctr)
fig_ctr.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 fig_clicks = px.bar(
# ----> 2     df_pages.sort_values("clicks", ascending=True),
#       3     x="clicks",
#       4     y="page_path",
#       5     orientation="h",
#       6     template="lifeline",
#       7     title=f"Top {TOP_N} Pages by Search Clicks",
#       8 )
#       9 fig_clicks.update_layout(height=700, margin={"l": 260})
#      10 lifeline_theme.add_lifeline_logo(fig_clicks)
#
# NameError: name 'df_pages' is not defined
